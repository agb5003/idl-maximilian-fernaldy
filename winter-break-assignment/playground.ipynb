# %%
L = [-10,20,-5,0,1,3,-11,6,5,20,15,-3,18,-12] #Still not work properly
def MergeSort(A):
  if len(A) > 1:
    Amiddle = int(len(A)/2)
    lessA = A[:Amiddle]
    moreA = A[Amiddle:]

    lessA = MergeSort(lessA)
    moreA = MergeSort(moreA)

    while moreA != []:
      moretoless = moreA.pop(-1)
      left=[]
      right=[]
      for i in lessA:
        if i <= moretoless:
          left = left + [i]
        if i > moretoless:
          right = right + [i]
      lessA = left + [moretoless] + right
    A = lessA
    
  return A

print(MergeSort(L))
# Out:
# [-12, -11, -10, -5, -3, 0, 1, 3, 5, 6, 15, 18, 20, 20]

# %%
L = [3,4,5,6]
R = []

for i in range(len(L)):
  R[i:i] = [str(L[i])]

print(R)
# Out:
# ['3', '4', '5', '6']
